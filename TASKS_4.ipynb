# %% [markdown]
# ## DATA ANALYSIS ON AMCATA DATA
#     The dataset was released by Aspiring Minds from the Aspiring Mind Employment Outcome 2015 (AMEO). The study is primarily limited only to students with engineering disciplines. The dataset contains the employment outcomes of engineering graduates as dependent variables (Salary, Job Titles, and Job Locations) along with the standardized scores from three different areas – cognitive skills, technical skills and personality skills. The dataset also contains demographic features. The dataset contains around 40 independent variables and 4000 data points.

# %%
import pandas as pd

# %%
df = pd.read_csv( r'C:\Users\Hello\Downloads\data.xlsx - Sheet1.csv')

# %%
df
# Out:
#      Unnamed: 0      ID     Salary           DOJ           DOL  \
# 0         train  203097   420000.0   6/1/12 0:00       present
# 1         train  579905   500000.0   9/1/13 0:00       present
# 2         train  810601   325000.0   6/1/14 0:00       present
# 3         train  267447  1100000.0   7/1/11 0:00       present
# 4         train  343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...         ...     ...        ...           ...           ...
# 3993      train   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888   320000.0   7/1/13 0:00       present
# 3996      train  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# ...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df
# Out:
#           ID     Salary           DOJ           DOL  \
# 0     203097   420000.0   6/1/12 0:00       present
# 1     579905   500000.0   9/1/13 0:00       present
# 2     810601   325000.0   6/1/14 0:00       present
# 3     267447  1100000.0   7/1/11 0:00       present
# 4     343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...      ...        ...           ...           ...
# 3993   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995  355888   320000.0   7/1/13 0:00       present
# 3996  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# 1               assistant manager            Indore      m  10/4/89 0:00
# 2                systems engineer           Chennai      f   8/3/92 0:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   DOJ                    3998 non-null   object
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   object
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
df
# Out:
#           ID     Salary           DOJ           DOL  \
# 0     203097   420000.0   6/1/12 0:00       present
# 1     579905   500000.0   9/1/13 0:00       present
# 2     810601   325000.0   6/1/14 0:00       present
# 3     267447  1100000.0   7/1/11 0:00       present
# 4     343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...      ...        ...           ...           ...
# 3993   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995  355888   320000.0   7/1/13 0:00       present
# 3996  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# 1               assistant manager            Indore      m  10/4/89 0:00
# 2                systems engineer           Chennai      f   8/3/92 0:00
# ...

# %%
df.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
df.describe(include="object")
# Out:
#                 DOJ      DOL        Designation    JobCity Gender  \
# count          3998     3998               3998       3998   3998
# unique           81       67                419        339      2
# top     7/1/14 0:00  present  software engineer  Bangalore      m
# freq            199     1875                539        627   3041
#
#                 DOB 10board 12board       Degree  \
# count          3998    3998    3998         3998
# unique         1872     275     340            4
# top     1/1/91 0:00    cbse    cbse  B.Tech/B.E.
# freq             11    1395    1400         3700
#
#                                    Specialization   CollegeState
# count                                        3998           3998
# unique                                         46             26
# top     electronics and communication engineering  Uttar Pradesh
# freq                                          880            915

# %%
df['GraduationYear'].value_counts()
# Out:
# 2013    1181
# 2014    1036
# 2012     847
# 2011     507
# 2010     292
# 2015      94
# 2009      24
# 2017       8
# 2016       7
# 0          1
# 2007       1
# Name: GraduationYear, dtype: int64

# %%
df[df["GraduationYear"]==0]
# Out:
#           ID    Salary          DOJ          DOL       Designation  \
# 2664  794381  325000.0  7/1/14 0:00  7/1/15 0:00  systems engineer
#
#          JobCity Gender            DOB  10percentage 10board  ...  \
# 2664  Chandigarh      m  12/17/91 0:00          89.0    cbse  ...
#
#       ComputerScience  MechanicalEngg ElectricalEngg  TelecomEngg  CivilEngg  \
# 2664               -1             446             -1           -1         -1
#
#      conscientiousness agreeableness  extraversion  nueroticism  \
# 2664            1.1336        0.3789       -0.2974      -0.3612
#
#       openess_to_experience
# 2664                 -1.244
#
# [1 rows x 38 columns]

# %%
df.GraduationYear = df['GraduationYear'].replace(0,2014)

# %%
df['DOL'].replace('present','2019-12-31', inplace = True)
df['DOL'] = pd.to_datetime(df['DOL'])
df['DOJ'] = pd.to_datetime(df['DOJ'])
df.head()
# Out:
#        ID     Salary        DOJ        DOL               Designation  \
# 0  203097   420000.0 2012-06-01 2019-12-31   senior quality engineer
# 1  579905   500000.0 2013-09-01 2019-12-31         assistant manager
# 2  810601   325000.0 2014-06-01 2019-12-31          systems engineer
# 3  267447  1100000.0 2011-07-01 2019-12-31  senior software engineer
# 4  343523   200000.0 2014-03-01 2015-03-01                       get
#
#      JobCity Gender           DOB  10percentage  \
# 0  Bangalore      f  2/19/90 0:00          84.3
# 1     Indore      m  10/4/89 0:00          85.4
# 2    Chennai      f   8/3/92 0:00          85.0
# 3    Gurgaon      m  12/5/89 0:00          85.6
# 4    Manesar      m  2/27/91 0:00          78.0
#
#                           10board  ...  ComputerScience  MechanicalEngg  \
# 0  board ofsecondary education,ap  ...               -1              -1
# 1                            cbse  ...               -1              -1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   DOJ                    3998 non-null   datetime64[ns]
#  3   DOL                    3998 non-null   datetime64[ns]
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   object
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
df['Period'] = df['DOL'].dt.year-df['DOJ'].dt.year

# %%
df.collegeGPA
# Out:
# 0       78.00
# 1       70.06
# 2       70.00
# 3       74.64
# 4       73.90
#         ...
# 3993    61.50
# 3994    77.30
# 3995    70.00
# 3996    70.42
# 3997    68.00
# Name: collegeGPA, Length: 3998, dtype: float64

# %%
df['DOB'] = pd.to_datetime(df['DOB'])
df['Age'] = 2019 - df['DOB'].dt.year

# %%
df
# Out:
#           ID     Salary        DOJ        DOL                  Designation  \
# 0     203097   420000.0 2012-06-01 2019-12-31      senior quality engineer
# 1     579905   500000.0 2013-09-01 2019-12-31            assistant manager
# 2     810601   325000.0 2014-06-01 2019-12-31             systems engineer
# 3     267447  1100000.0 2011-07-01 2019-12-31     senior software engineer
# 4     343523   200000.0 2014-03-01 2015-03-01                          get
# ...      ...        ...        ...        ...                          ...
# 3993   47916   280000.0 2011-10-01 2012-10-01            software engineer
# 3994  752781   100000.0 2013-07-01 2013-07-01             technical writer
# 3995  355888   320000.0 2013-07-01 2019-12-31  associate software engineer
# 3996  947111   200000.0 2014-07-01 2015-01-01           software developer
# 3997  324966   400000.0 2013-02-01 2019-12-31      senior systems engineer
#
#                JobCity Gender        DOB  10percentage  \
# ...

# %%
df.JobCity=df["JobCity"].apply(lambda x : x.replace('-1','Not Mentioned') if '-1' in x else x )
df['JobCity'] = df['JobCity'].apply(lambda x : x.upper().strip())

# %%
df.JobCity.value_counts()
# Out:
# BANGALORE           665
# NOT MENTIONED       461
# NOIDA               389
# HYDERABAD           368
# PUNE                327
#                    ...
# VANDAVASI             1
# ROHTAK                1
# UNA                   1
# SALEM                 1
# ASIFABADBANGLORE      1
# Name: JobCity, Length: 232, dtype: int64

# %%
a=df.JobCity.unique()

# %%
a.sort()

# %%
a
# Out:
# array(['A-64,SEC-64,NOIDA', 'AGRA', 'AHMEDABAD', 'AHMEDNAGAR',
#        'AL JUBAIL,SAUDI ARABIA', 'ALLAHABAD', 'ALWAR', 'AM', 'AMBALA',
#        'AMBALA CITY', 'ANGUL', 'ARIYALUR', 'ASANSOL', 'ASIFABADBANGLORE',
#        'AURANGABAD', 'AUSTRALIA', 'BADDI HP', 'BAHADURGARH', 'BANAGALORE',
#        'BANAGLORE', 'BANGALORE', 'BANGLORE', 'BANKURA', 'BARELI',
#        'BARIPADA', 'BARODA', 'BATHINDA', 'BEAWAR', 'BELGAUM', 'BELLARY',
#        'BENGALURU', 'BHAGALPUR', 'BHARUCH', 'BHILAI', 'BHIWADI', 'BHOPAL',
#        'BHUBANESHWAR', 'BHUBANESWAR', 'BHUBNESHWAR', 'BIHAR', 'BIKANER',
#        'BILASPUR', 'BULANDSHAHAR', 'BUNDI', 'BURDWAN', 'CALICUT',
#        'CHANDIGARH', 'CHANDRAPUR', 'CHENNAI', 'CHENNAI & MUMBAI',
#        'CHENNAI, BANGALORE', 'CHEYYAR', 'COIMBATORE', 'DAMAN AND DIU',
#        'DAMMAM', 'DAUSA', 'DEHRADUN', 'DELHI', 'DELHI/NCR', 'DHANBAD',
#        'DHARAMSHALA', 'DHARMAPURI', 'DHARUHERA', 'DUBAI', 'DURGAPUR',
# ...

# %%
df['JobCity']=df['JobCity'].replace(to_replace='A-64,SEC-64,NOIDA',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='AM',value='AMBALA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='AMBALA CITY',value='AMBALA',regex=False)

df['JobCity']=df['JobCity'].replace(to_replace='BANAGALORE',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='BANAGLORE',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='ASIFABADBANGLORE',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='BENGALURU',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='BANGLORE',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='BHUBANESHWAR',value='BHUBANESWAR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='BHUBNESHWAR',value='BHUBANESWAR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='CHENNAI & MUMBAI',value='CHENNAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='CHENNAI, BANGALORE',value='CHENNAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='DELHI/NCR',value='DELHI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='DUBAI',value='INDIA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GAZIABAAD',value='GHAZIABAD',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GAZIBAAD',value='GHAZIABAD',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='INDIRAPURAM, GHAZIABAD',value='GHAZIABAD',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GANDHINAGAR',value='GANDHI NAGAR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GREATER NOIDA',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GURAGAON',value='GURGAON',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GURGA',value='GURGAON',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GURGOAN',value='GURGAON',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='HDERABAD',value='HYDERABAD',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='HYDERABAD(BHADURPALLY)',value='HYDERABAD',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='JEDDAH SAUDI ARABIA',value='INDIA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='KOCHI/COCHIN',value='KOCHI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='KOCHI/COCHIN, CHENNAI AND COIMBATORE',value='KOCHI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='KOLKATA`',value='KOLKATA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='KUDANKULAM ,TARAPUR',value='KUDANKULAM',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='LATUR (MAHARASHTRA )',value='LATUR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='METTUR, TAMIL NADU',value='METTUR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='MUZAFFARNAGAR',value='MUZAFFARPUR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='MUZZAFARPUR',value='MUZAFFARPUR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='NAVI MUMBAI',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='NAVI MUMBAI , HYDERABAD',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='NEW DEHLI',value='DELHI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='NEW DELHI',value='DELHI',regex=False)

df['JobCity']=df['JobCity'].replace(to_replace='DEHLI',value='DELHI',regex=False)


df['JobCity']=df['JobCity'].replace(to_replace='NEW DELHI - JAISALMER',value='DEHLI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='NOUDA',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='PONDI',value='PONDICHERRY',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='PONDY',value='PONDICHERRY',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='PUNR',value='PUNE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='RAYAGADA, ODISHA',value='ODISHA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='ORISSA',value='ODISHA',regex=False)



df['JobCity']=df['JobCity'].replace(to_replace='SADULPUR,RAJGARH,DISTT-CHURU,RAJASTHAN',value='SADULPUR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='SONIPAT',value='SONEPAT',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='TIRUPATI',value='TIRUPATHI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='TECHNOPARK, TRIVANDRUM',value='TRIVANDRUM',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='UNA',value='UNNAO',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='VIZAG',value='VISAKHAPATNAM',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='VSAKHAPTTNAM',value='VISAKHAPATNAM',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='KALMAR, SWEDEN',value='KALMAR',regex=False)

# %%
df.JobCity.value_counts().head(60)
# Out:
# BANGALORE             687
# NOT MENTIONED         461
# NOIDA                 420
# HYDERABAD             370
# PUNE                  328
# CHENNAI               315
# DELHI                 227
# GURGAON               223
# MUMBAI                154
# KOLKATA               120
# JAIPUR                 53
# LUCKNOW                41
# MYSORE                 40
# BHUBANESWAR            40
# CHANDIGARH             28
# INDORE                 25
# COIMBATORE             21
# AHMEDABAD              19
# BHOPAL                 19
# GHAZIABAD              18
# FARIDABAD              18
# KOCHI                  16
# MOHALI                 13
# DEHRADUN               11
# MANGALORE              11
# TRIVANDRUM             11
# VISAKHAPATNAM          11
# NAGPUR                 11
# KANPUR                  9
# PONDICHERRY             8
# THANE                   7
# THIRUVANANTHAPURAM      7
# JABALPUR                7
# PATNA                   7
# JODHPUR                 5
# ...

# %%
df['Designation']=df['Designation'].replace(to_replace='dotnet developer',value='.net developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='.net web developer',value='.net developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='assistant system engineer - trainee',value='assistant system engineer trainee',regex=False)
df['Designation']=df['Designation'].replace(to_replace='assistant systems engineer',value='assistant system engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='associate software engg',value='associate software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='business development managerde',value='business development manager',regex=False)
df['Designation']=df['Designation'].replace(to_replace='business systems analyst',value='business system analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='co faculty',value='computer faculty',regex=False)
df['Designation']=df['Designation'].replace(to_replace='db2 dba',value='databapplication support engineer administrator',regex=False)
df['Designation']=df['Designation'].replace(to_replace='dba',value='databapplication support engineer administrator',regex=False)
df['Designation']=df['Designation'].replace(to_replace='executive engg',value='executive engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='front end web developer',value='front end developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='graduate trainee engineer',value='graduate engineer trainee',regex=False)
df['Designation']=df['Designation'].replace(to_replace='ase',value='application support engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='hr executive',value='executive hr',regex=False)
df['Designation']=df['Designation'].replace(to_replace='jr. software engineer',value='junior software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='operations engineer and jetty handling',value='operations engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='qa analyst',value='quality analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='qa engineer',value='quality engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='qa trainee',value='quality trainee',regex=False)
df['Designation']=df['Designation'].replace(to_replace='r & d',value='r&d engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='rf/dt engineer',value='rf engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='sales and service engineer',value='sales & service engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='seo',value='seo analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software devloper',value='software developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software eng',value='software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software engg',value='software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software engineere',value='software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software enginner',value='software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software test engineer (etl)',value='software test engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software test engineerte',value='software test engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='sr. engineer',value='senior engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='team leader',value='team lead',regex=False)
df['Designation']=df['Designation'].replace(to_replace='systems analyst',value='system analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='systems administrator',value='system administrator',regex=False)
df['Designation']=df['Designation'].replace(to_replace='testing engineer',value='test engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='web designer and joomla administrator',value='web designer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='web designer and seo',value='web designer',regex=False)

# %%
df.Designation.nunique()
# Out:
# 384

# %%
df.Specialization.unique()
# Out:
# array(['computer engineering',
#        'electronics and communication engineering',
#        'information technology', 'computer science & engineering',
#        'mechanical engineering', 'electronics and electrical engineering',
#        'electronics & telecommunications',
#        'instrumentation and control engineering', 'computer application',
#        'electronics and computer engineering', 'electrical engineering',
#        'applied electronics and instrumentation',
#        'electronics & instrumentation eng',
#        'information science engineering', 'civil engineering',
#        'mechanical and automation', 'industrial & production engineering',
#        'control and instrumentation engineering',
#        'metallurgical engineering',
#        'electronics and instrumentation engineering',
#        'electronics engineering', 'ceramic engineering',
#        'chemical engineering', 'aeronautical engineering', 'other',
# ...

# %%
df['Specialization']=df['Specialization'].replace(to_replace='electronics & instrumentation eng',value='electronics and instrumentation engineering',regex=False)
df['Specialization']=df['Specialization'].replace(to_replace='computer science',value='computer science and engineering',regex=False)
df['Specialization']=df['Specialization'].replace(to_replace='computer science & engineering',value='computer science and engineering',regex=False)
df['Specialization']=df['Specialization'].replace(to_replace='computer science and technology',value='computer science and engineering',regex=False)

# %%
df.Specialization.unique()
# Out:
# array(['computer engineering',
#        'electronics and communication engineering',
#        'information technology', 'computer science and engineering',
#        'mechanical engineering', 'electronics and electrical engineering',
#        'electronics & telecommunications',
#        'instrumentation and control engineering', 'computer application',
#        'electronics and computer engineering', 'electrical engineering',
#        'applied electronics and instrumentation',
#        'electronics and instrumentation engineering',
#        'information science engineering', 'civil engineering',
#        'mechanical and automation', 'industrial & production engineering',
#        'control and instrumentation engineering',
#        'metallurgical engineering', 'electronics engineering',
#        'ceramic engineering', 'chemical engineering',
#        'aeronautical engineering', 'other', 'biotechnology',
#        'embedded systems technology', 'electrical and power engineering',
# ...

# %%
df
# Out:
#           ID     Salary        DOJ        DOL                  Designation  \
# 0     203097   420000.0 2012-06-01 2019-12-31      senior quality engineer
# 1     579905   500000.0 2013-09-01 2019-12-31            assistant manager
# 2     810601   325000.0 2014-06-01 2019-12-31             systems engineer
# 3     267447  1100000.0 2011-07-01 2019-12-31     senior software engineer
# 4     343523   200000.0 2014-03-01 2015-03-01                          get
# ...      ...        ...        ...        ...                          ...
# 3993   47916   280000.0 2011-10-01 2012-10-01            software engineer
# 3994  752781   100000.0 2013-07-01 2013-07-01             technical writer
# 3995  355888   320000.0 2013-07-01 2019-12-31  associate software engineer
# 3996  947111   200000.0 2014-07-01 2015-01-01           software developer
# 3997  324966   400000.0 2013-02-01 2019-12-31      senior systems engineer
#
#         JobCity Gender        DOB  10percentage  \
# ...

# %%
df.CollegeState.unique()
# Out:
# array(['Andhra Pradesh', 'Madhya Pradesh', 'Uttar Pradesh', 'Delhi',
#        'Karnataka', 'Tamil Nadu', 'West Bengal', 'Maharashtra', 'Haryana',
#        'Telangana', 'Orissa', 'Punjab', 'Kerala', 'Gujarat', 'Rajasthan',
#        'Chhattisgarh', 'Uttarakhand', 'Jammu and Kashmir', 'Jharkhand',
#        'Himachal Pradesh', 'Bihar', 'Assam', 'Goa', 'Sikkim',
#        'Union Territory', 'Meghalaya'], dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['f', 'm'], dtype=object)

# %%
df.head()
# Out:
#        ID     Salary        DOJ        DOL               Designation  \
# 0  203097   420000.0 2012-06-01 2019-12-31   senior quality engineer
# 1  579905   500000.0 2013-09-01 2019-12-31         assistant manager
# 2  810601   325000.0 2014-06-01 2019-12-31          systems engineer
# 3  267447  1100000.0 2011-07-01 2019-12-31  senior software engineer
# 4  343523   200000.0 2014-03-01 2015-03-01                       get
#
#      JobCity Gender        DOB  10percentage                         10board  \
# 0  BANGALORE      f 1990-02-19          84.3  board ofsecondary education,ap
# 1     INDORE      m 1989-10-04          85.4                            cbse
# 2    CHENNAI      f 1992-08-03          85.0                            cbse
# 3    GURGAON      m 1989-12-05          85.6                            cbse
# 4    MANESAR      m 1991-02-27          78.0                            cbse
#
#    ...  ElectricalEngg  TelecomEngg CivilEngg  conscientiousness  \
# ...

# %% [markdown]
# ## The above data is clear and ready for data analysis performance

# %%
y = df['10board'].unique()
y.sort()

# %%
y
# Out:
# array(['0', 'aisse', 'andhra pradesh board ssc',
#        'andhra pradesh state board', 'anglo indian', 'ap state board',
#        'ap state board for secondary education', 'apsche', 'apssc',
#        'aurangabad board', 'bharathi matriculation school', 'bihar',
#        'bihar board', 'bihar examination board, patna',
#        'bihar school examination board',
#        'bihar school examination board patna',
#        'bihar secondary education board,patna', 'biharboard',
#        'board of  secondary education',
#        'board of high school and intermediate education uttarpradesh',
#        'board of intermediate education',
#        'board of school education harayana',
#        'board of school education haryana',
#        'board of school education uttarakhand',
#        'board of secendary education orissa',
#        'board of secondaray education', 'board of secondary education',
#        'board of secondary education (bse) orissa',
# ...

# %%
Keywords=['pseb','punjab school education board, mohali']
df['10board'] = df['10board'].replace(Keywords, 'Punjab BSE', regex=False)

Keywords=['seba', 'seba(assam)']
df['10board'] = df['10board'].replace(Keywords, 'Assam BSE', regex=False)

# %%
df['10board']=df['10board'].replace(to_replace= 'apsche',value='AISSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'anglo indian',value='AISSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'hP BSE',value='HP BSE',regex=False)

Keywords=['stmary higher secondary', "stmary's convent inter college"]
df['10board'] = df['10board'].replace(Keywords, 'UP BSE', regex=False)

# %%
df['10board']=df['10board'].replace(to_replace= 'council for indian school certificate examination',value='ICSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'certificate of middle years program of ib',value='ICSE',regex=False)

# %%
Keywords=['board of  secondary education','board of NOT MENTIONED','secondary school cerfificate', 'secondary school certificate',
       'secondary school education', 'secondary school of education',
       'secondary state certificate', 'ssc', 'ssc regular', 'sslc',
       'sslc board', 'state', 'state board', 'state board ','state bord', 'stateboard']
df['10board'] = df['10board'].replace(Keywords, 'NOT MENTIONED', regex=False)

# %%
Keywords=['latur', 'latur board','sss pune', 'pune board','pune']
df['10board'] = df['10board'].replace(Keywords, 'MAHARASHTRA BSE', regex=False)

# %%
df['10board']=df['10board'].replace(to_replace= 'cicse',value='ICSE',regex=False)
df['10board'].nunique()
# Out:
# 251

# %%
df['10board']=df['10board'].replace(to_replace= 'HP BSE of school education',value='HP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'HP BSE,board',value='HP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'HP BSEe',value='hP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=  'cgOrissa BSE',value='CG BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=  'cgOrissa BSE raipur',value='CG BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=   'state borad hp',value='HP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=  'sslc,Karnataka BSE',value='Karnatak BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=  'cgOrissa BSE',value='CG BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'icse',value='ICSE',regex=False)
df['10board']=df['10board'].replace(to_replace='icse board',value='ICSE',regex=False)
df['10board']=df['10board'].replace(to_replace='icse board , new delhi',value='ICSE',regex=False)

df['10board']=df['10board'].replace(to_replace='education board of Kerala BSE',value='Kearala BSE',regex=False)

# %%
df['10board']=df['10board'].replace(to_replace= 'bharathi MP BSEulation school',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'MP BSE board',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'MP BSE board bhopal',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=  'MP BSE state board',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=  'MP BSEOrissa BSE',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=  'MP BSEboard',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=  'MP BSEulation',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace=  'MP BSEulation board',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'little jacky MP BSE higher secondary school',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='holy cross MP BSEulation hr sec school',value='MP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='sri kannika parameswari highier secondary school, udumalpet',value='TN BSE',regex=False)

# %%
Keywords =['cgbse', 'cgbse raipur']
df['10board'] = df['10board'].replace(Keywords, 'CG BSE', regex=False)

# %%
Keywords =['himachal pradesh board',  'himachal pradesh board of school education', 'hsc', 'hsce', 'hse','hse,board']
df['10board'] = df['10board'].replace(Keywords, 'HP BSE', regex=False)

# %%
 Keywords = ['ghseb', 'gseb', 'gsheb', 'gujarat board', 'gujarat state board']
df['10board'] = df['10board'].replace(Keywords, 'GJ BSE', regex=False)

# %%
Keywords=['state board of secondary education( ssc)', 'board of ssc', 'cluny',
       'holy cross matriculation hr sec school',
       'little jacky matric higher secondary school',]
df['10board'] = df['10board'].replace(Keywords, 'NOT MENTIONED', regex=False)

# %%
df['10board']=df['10board'].replace(to_replace= 'state Orissa BSE( ssc)',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'mp-Orissa BSE',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'hse,orissa',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'board of ssc education andhra pradesh',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'aisse',value='AISSE',regex=False)

df['10board']=df['10board'].replace(to_replace= 'Orissa BSE(Orissa BSE) orissa',value='Orissa BSE',regex=False)

df['10board']=df['10board'].replace(to_replace= 'Orissa BSE orissa',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'Orissa BSE (Orissa BSE) orissa',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'Orissa BSE(board of secondary education)',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'Orissa BSE, odisha',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Orissa BSE,odisha',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Orissa BSE,orissa',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Orissa BSEb',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Orissa BSEb ,patna',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Orissa BSEb patna',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Orissa BSEb, patna',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Orissa BSEb,patna',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Orissa BSEmp',value='Orissa BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Orissa BSEpatna',value='Orissa BSE',regex=False)

# %%
Keywords = ['board of secendary education orissa',
       'board of secondaray education', 'board of secondary education',
       'board of secondary education (Orissa BSE) orissa',
       'board of secondary education orissa',
       'board of secondary education(Orissa BSE) orissa',
       'board of secondary education,odisha',
       'board of secondary education,orissa',
       'board of secondary school education']
df['10board'] = df['10board'].replace(Keywords, 'Orissa BSE', regex=False)

# %%
df['10board']=df['10board'].replace(to_replace='CBSE[gulf zone]',value='CBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Haryana BSE,(Haryana BSE)',value='Haryana BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Karnataka BSE (keeb)',value='Karnataka BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='Karnataka BSE(Karnataka BSE)',value='Karnataka BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='west bengal board of secondary examination (WB BSE)',value='WB BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='stjosephs girls higher sec school,dindigul',value='TN BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='stjoseph of cluny matrhrsecschool,neyveli,cuddalore district',value='TN BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='state(Karnataka BSE)',value='Karnataka BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='state board of karnataka',value='Karnataka BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='state board of secondary education, ap',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='ssc MAHARASHTRA BSE',value='MAHARASHTRA BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='MAHARASHTRA BSE state(latur board)',value='MAHARASHTRA BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='MAHARASHTRA BSE',value='MAHARASHTRA BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='0',value='NOT MENTIONED',regex=False)


df['10board']=df['10board'].replace(to_replace='jharkhand secondary examination board (ranchi)',value='Jharkhand BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='state board (jac, ranchi)',value='Jharkhand BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='kalaimagal matriculation higher secondary school',value='TN BSE',regex=False)
df['10board']=df['10board'].replace(to_replace='RJ BSE (state board)',value='RJ BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'board of secondary education,rajasthan(RJ BSE)',value='RJ BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'bright way college, (UP BSE)',value='UP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'Kerala BSE(Karnataka BSE)',value='Kerala BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'UP BSE(allahabad)',value='UP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'board of high school and intermediate education uttarpradesh',value='UP BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'board of school education uttarakhand',value='UK BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'board of secondary education,andhra pradesh',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'bse, odisha',value='Orissa BSE',regex=False)

# %%
Keywords =['mp-bse', 'mpbse',
       'state boardmp board ','madhya pradesh board', 'maticulation', 'matric', 'matric board',
       'matriculation', 'matriculation board', 'metric',
       'mirza ahmed ali baig', 'mp', 'mp board', 'mp board bhopal',
       'mp state board', 'mpOrissa BSE', 'mpboard']
df['10board'] = df['10board'].replace(Keywords, 'MP BSE', regex=False)

# %%
Keywords = ['bharathi matriculation school',
       'board of secondary education (bse) orissa',
       'board of secondary education(bse) orissa','board secondary  education', 'bsc,orissa', 'bse','bse(board of secondary education)', 'bse, odisha', 'bse,odisha','bse,orissa']
df['10board'] = df['10board'].replace(Keywords, 'Orissa BSE', regex=False)

# %%
Keywords = ['RJ BSE',
       'RJ BSE (state board)', 'RJ BSE ajmer',
       'RJ BSE of secondary education', 'RJ BSE,ajmer','board of secondary education rajasthan','board of secondary education, rajasthan'
           ,'board of secondary education,rajasthan(RJ BSE)']
df['10board'] = df['10board'].replace(Keywords, 'RJ BSE', regex=False)

# %%
Keywords = ['board of secondary education,rajasthan(rbse)','rajasthan board','rajasthan board ajmer', 'rajasthan board of secondary education','rbse', 'rbse (state board)', 'rbse,ajmer', 'sarada high scchool','school secondary education, andhra pradesh','secondary board of rajasthan','secondary education board of rajasthan']
df['10board'] = df['10board'].replace(Keywords, 'RJ BSE', regex=False)

# %%
Keywords = ['board of intermediate education','uttarakhand board', 'uttaranchal shiksha avam pariksha parishad',
       'uttaranchal state board', 'uttrakhand board', 'uttranchal board','board of intermediate education']
df['10board'] = df['10board'].replace(Keywords, 'UK BSE', regex=False)

# %%
Keywords=['tamil nadu state', 'tamilnadu matriculation board',
       'tamilnadu state board', 'tn state board']
df['10board'] = df['10board'].replace(Keywords, 'TN BSE', regex=False)

# %%
Keywords =['ssc maharashtra board','MAHARASHTRA BSE', 'MAHARASHTRA BSE state(latur board)','mhsbse','MAHARASHTRA BSE',
       'MAHARASHTRA BSE state(latur board)','MAHARASHTRA BSE MAHARASHTRA BSE board', 'MAHARASHTRA BSE board',
       'MAHARASHTRA BSE board, pune',
       'MAHARASHTRA BSE board,MAHARASHTRA BSE',
       'MAHARASHTRA BSE divisional board', 'MAHARASHTRA BSE satate board',
       'MAHARASHTRA BSE sate board',
       'MAHARASHTRA BSE state boar of secondary and higher secondary education',
       'MAHARASHTRA BSE state board',
       'MAHARASHTRA BSE state board for ssc',
       'MAHARASHTRA BSE state board mumbai divisional board',
       'MAHARASHTRA BSE state board of secondary & higher secondary education',
       'MAHARASHTRA BSE state board of secondary and higher secondary education',
       'MAHARASHTRA BSE state board of secondary and higher secondary education,pune',
       'MAHARASHTRA BSE state board pune',
       'MAHARASHTRA BSE state board,pune',
       'MAHARASHTRA BSE state(latur board)','MAHARASHTRA BSE for ssc',
       'MAHARASHTRA BSE mumbai divisional board',
       'MAHARASHTRA BSE of secondary & higher secondary education',
       'MAHARASHTRA BSE of secondary and higher secondary education',
       'MAHARASHTRA BSE of secondary and higher secondary education,pune',
       'MAHARASHTRA BSE pune', 'MAHARASHTRA BSE state(latur board)',
       'MAHARASHTRA BSE, pune', 'MAHARASHTRA BSE,MAHARASHTRA BSE',
       'MAHARASHTRA BSE,pune','MAHARASHTRA BSE',
       'MAHARASHTRA BSE state(latur board)', 'MAHARASHTRA BSE,pune']
df['10board'] = df['10board'].replace(Keywords, 'MAHARASHTRA BSE', regex=False)

# %%
df['10board']=df['10board'].replace(to_replace= 'MAHARASHTRA BSE',value='MAHARASHTRA BSE',regex=False)
df['10board']=df['10board'].replace(to_replace= 'MAHARASHTRA BSE board',value='MAHARASHTRA BSE',regex=False)

# %%
Keywords=['bright way college, (UP BSE)','UP BSE(allahabad)']
df['10board'] = df['10board'].replace(Keywords, 'UP BSE', regex=False)

# %%
Keywords=['bright way college, (up board)', 'bseb', 'bseb ,patna',
       'bseb patna', 'bseb, patna', 'bseb,patna', 'bsemp', 'bsepatna','bright way college, (UP BSE)','UP BSE(allahabad)','UP BSE board allahabad',
       'UP BSE board,allahabad', 'UP BSE borad', 'UP BSE bord',
       'UP BSE bourd', 'UP BSE(allahabad)', 'UP BSE-board', 'UP BSEbhsie',
       'UP BSEboard','u p', 'u p board',
       'ua', 'up', 'up baord', 'up board', 'up board , allahabad',
       'up board allahabad', 'up board,allahabad', 'up borad', 'up bord',
       'up bourd', 'up(allahabad)', 'up-board', 'upbhsie', 'upboard',
       'uttar pradesh', 'uttar pradesh board','UP BSE',
       'UP BSE baord', 'UP BSE board', 'UP BSE board , allahabad',
       'UP BSE board allahabad', 'UP BSE board,allahabad', 'UP BSE borad',
       'UP BSE bord', 'UP BSE bourd', 'UP BSE(allahabad)', 'UP BSE-board',
       'UP BSEbhsie', 'UP BSEboard','UP BSE',
       'UP BSE , allahabad', 'UP BSE(allahabad)']
df['10board'] = df['10board'].replace(Keywords, 'UP BSE', regex=False)

# %%
Keywords =['west bengal board of secondary examination (WB BSE)','state board - WB BSE : WB BSE','west bengal board of secondary examination (WB BSE)','wbbsce', 'wbbse', 'west bengal  board of secondary education',
       'west bengal board of secondary education','state board - west bengal board of secondary education : wbbse',
       'west bengal board of secondary eucation',
       'west bengal board of secondary examination (wbbse)','west bengal board of secondary examination (WB BSE)']
df['10board'] = df['10board'].replace(Keywords, 'WB BSE', regex=False)

# %%
Keywords=['MAHARASHTRA BSE,MAHARASHTRA BSE','MAHARASHTRA BSE divisional board','MAHARASHTRA BSE state board','MAHARASHTRA BSE satate board',
       'MAHARASHTRA BSE state board mumbai divisional board',
       'dav public school,hehal','MAHARASHTRA BSE board','MAHARASHTRA BSE state(latur board)','MAHARASHTRA BSE MAHARASHTRA BSE board','MAHARASHTRA BSE board, pune', 'MAHARASHTRA BSE state board of secondary & higher secondary education','aurangabad board',
       'MAHARASHTRA BSE state board of secondary and higher secondary education',
       'MAHARASHTRA BSE state boar of secondary and higher secondary education','maharashtra', 'maharashtra board',
       'maharashtra board, pune', 'maharashtra nasik board',
       'maharashtra satate board', 'maharashtra sate board',
       'maharashtra state boar of secondary and higher secondary education',
       'maharashtra state board', 'maharashtra state board for ssc',
       'maharashtra state board mumbai divisional board',
       'maharashtra state board of secondary & higher secondary education',
       'maharashtra state board of secondary and higher secondary education',
       'maharashtra state board of secondary and higher secondary education,pune',
       'maharashtra state board pune', 'maharashtra state board,pune',
       'maharashtra state(latur board)', 'maharastra board','ms board', 'msbshse,pune', 'mumbai board',
       'nagpur', 'nagpur board', 'nagpur board,nagpur',
       'nagpur divisional board', 'nashik board', 'nasik']
df['10board'] = df['10board'].replace(Keywords, 'MAHARASHTRA BSE', regex=False)

# %%
Keywords=['education board of kerala','kerala','Kerala BSE divisional board, MAHARASHTRA BSE',
       'Kerala BSE state board', 'Kerala BSE state technical education',
       'Kerala BSE university', 'Kerala BSE(Karnataka BSE)','kerala state board', 'kerala state technical education',
       'kerala university', 'kiran english medium high school',
       'kolhapur', 'kolhapur divisional board, maharashtra', 'ksbe',
       'kseb', 'kseeb']
df['10board'] = df['10board'].replace(Keywords, 'Kerala BSE', regex=False)

# %%
Keywords=['Karnataka BSE(Karnataka BSE)','state(karnataka board)','kseeb(karnataka secondary education examination board)', 'ksseb','karantaka secondary education and examination borad', 'karnataka',
       'ksseb(karnataka state board)','karnataka board', 'karnataka board of higher education',
       'karnataka board of secondary education',
       'karnataka education board', 'karnataka education board (keeb)',
       'karnataka secondary board', 'karnataka secondary education',
       'karnataka secondary education board','sslc,karnataka',
       'karnataka secondary education examination board',
       'karnataka secondary eduction',
       'karnataka secondary school of examination',
       'karnataka secondory education board',
       'karnataka sslc board bangalore', 'karnataka state board',
       'karnataka state education examination board',
       'karnataka state examination board',
       'karnataka state secondary education board','Karnataka BSE', 'Karnataka BSE (keeb)',
       'Karnataka BSE board', 'Karnataka BSE examination board',
       'Karnataka BSE of higher education',
       'Karnataka BSE of secondary education',
       'Karnataka BSE(Karnataka BSE)','Karnataka BSE',
       'Karnataka BSE (keeb)', 'Karnataka BSE(Karnataka BSE)']
df['10board'] = df['10board'].replace(Keywords, 'Karnataka BSE', regex=False)

# %%
Keywords=[ 'j & k bord',
       'j&k state board of school education',
       'jawahar navodaya vidyalaya', 'jbse,jharkhand',
       'jharkhand academic council', 'jharkhand accademic council',
       'jharkhand acedemic council', 'jharkhand secondary board',
       'jharkhand secondary education board',
       'jharkhand secondary examination board (ranchi)',
       'jharkhand secondary examination board,ranchi', 'jkbose', 'jseb', 'state board (jac, ranchi)']
df['10board'] = df['10board'].replace(Keywords, 'Jharkhand BSE', regex=False)

# %%
Keywords = ['Haryana BSE,(Haryana BSE)','Haryana BSE,(Haryana BSE)','board of school education harayana',
       'board of school education haryana','haryana board of school education',
       'haryana board of school education,(hbse)', 'hbsc', 'hbse','Haryana BSE,(Haryana BSE)','Haryana BSE,(Haryana BSE)']
df['10board'] = df['10board'].replace(Keywords, 'Haryana BSE', regex=False)

# %%
Keywords = ['Bihar BSE patna','Bihar BSE board',
       'Bihar BSE examination board, patna',
       'Bihar BSE school examination board',
       'Bihar BSE school examination board patna',
       'Bihar BSE secondary education board,patna', 'Bihar BSEboard','bihar',
       'bihar board', 'bihar examination board, patna',
       'bihar school examination board',
       'bihar school examination board patna',
       'bihar secondary education board,patna', 'biharboard','Bihar BSE', 'Bihar BSE board',
       'Bihar BSE examination board, patna',
       'Bihar BSE school examination board',
       'Bihar BSE school examination board patna',
       'Bihar BSE secondary education board,patna', 'Bihar BSEboard','Bihar BSE patna','CBSE[gulf zone]', 'CBSEboard',]
df['10board'] = df['10board'].replace(Keywords, 'Bihar BSE', regex=False)

# %%
df['10board']=df['10board'].replace(to_replace='andhra pradesh board ssc',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='andhra pradesh state board',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='ap state board',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='ap state board for secondary education',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='apssc',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='board of secondary education - andhra pradesh',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='board of secondary education, andhra pradesh',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='board of secondary education,andhara pradesh',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='board of secondary education,ap',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='board ofsecondary education,ap',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='ssc board of andrapradesh',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='ssc-andhra pradesh',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='state board of secondary education, andhra pradesh',value='APBSE',regex=False)
df['10board']=df['10board'].replace(to_replace='state board of secondary education,andhra pradesh',value='APBSE',regex=False)

# %%
df['10board']=df['10board'].replace(to_replace= 'Kearala BSE',value='Kerala BSE',regex=False)

# %%
from fuzzywuzzy import process
# Out:
# C:\Users\Hello\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
Keywords = ['dav public school sec 14',
       'gyan bharati school', 'kea', 'national public school','delhi board', 'delhi public school',
       'don bosco maatriculation school','cbsc', 'cbse', 'cbse ', 'cbse board', 'cbse[gulf zone]',
       'central board of secondary education',
       'central board of secondary education, new delhi','CBSE', 'CBSE ', 'CBSE board', 'CBSE, new delhi',
       'CBSE[gulf zone]','CBSE[gulf zone]']
df['10board'] =  df['10board'].replace(Keywords, 'CBSE', regex=False)

# %%
def correct (Target_value="",choice=[],threshold=80):
    match,score = process.extractOne(Target_value,choice)
    if score>=threshold:
        return match
    else:
        return Target_value

# %%
a=df['12board'].unique()
a.sort()
a
# Out:
# array([' board of intermediate', ' upboard', '0', 'ahsec', 'aissce',
#        'aligarh muslim university', 'all india board',
#        'amravati divisional board',
#        'andhpradesh board of intermediate education', 'andhra board',
#        'andhra pradesh', 'andhra pradesh board of secondary education',
#        'andhra pradesh state board', 'ap board',
#        'ap board for intermediate education', 'ap intermediate board',
#        'apbie', 'apbsc', 'apsb', 'aurangabad board',
#        'baord of intermediate education', 'bciec,patna', 'bice', 'bie',
#        'bieap', 'biec', 'biec patna', 'biec, patna', 'biec,patna',
#        'biec-patna', 'bihar', 'bihar board',
#        'bihar intermediate education council',
#        'bihar intermediate education council, patna',
#        'bihar school examination board patna',
#        'board fo intermediate education, ap',
#        'board of high school and intermediate education uttarpradesh',
# ...

# %%
df['12board'] =  df['12board'].replace('0', 'Other', regex=False)

# %%
df
# Out:
#           ID     Salary        DOJ        DOL                  Designation  \
# 0     203097   420000.0 2012-06-01 2019-12-31      senior quality engineer
# 1     579905   500000.0 2013-09-01 2019-12-31            assistant manager
# 2     810601   325000.0 2014-06-01 2019-12-31             systems engineer
# 3     267447  1100000.0 2011-07-01 2019-12-31     senior software engineer
# 4     343523   200000.0 2014-03-01 2015-03-01                          get
# ...      ...        ...        ...        ...                          ...
# 3993   47916   280000.0 2011-10-01 2012-10-01            software engineer
# 3994  752781   100000.0 2013-07-01 2013-07-01             technical writer
# 3995  355888   320000.0 2013-07-01 2019-12-31  associate software engineer
# 3996  947111   200000.0 2014-07-01 2015-01-01           software developer
# 3997  324966   400000.0 2013-02-01 2019-12-31      senior systems engineer
#
# ...

# %% [markdown]
# ## NOW DATA ANALYSIS PART

# %% [markdown]
# ## UNIVARIATE ANALYSIS ON CATEGORICAL OR DESCRETE COLUMNS

# %%
y=df.JobCity.value_counts()[:10]
x=y.index
x,y
# Out:
# (Index(['BANGALORE', 'NOT MENTIONED', 'NOIDA', 'HYDERABAD', 'PUNE', 'CHENNAI',
#         'DELHI', 'GURGAON', 'MUMBAI', 'KOLKATA'],
#        dtype='object'),
#  BANGALORE        687
#  NOT MENTIONED    461
#  NOIDA            420
#  HYDERABAD        370
#  PUNE             328
#  CHENNAI          315
#  DELHI            227
#  GURGAON          223
#  MUMBAI           154
#  KOLKATA          120
#  Name: JobCity, dtype: int64)

# %%
import matplotlib.pyplot as plt
plt.title("JOB CITY ")
plt.xlabel("CITY")
plt.ylabel("NO_OF_EMPLOYEES")
plt.xticks(rotation=90)
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
import seaborn as sns
sns.countplot(data=df,x=df.Gender)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
a = df.columns

# %%
df.Degree.unique()
# Out:
# array(['B.Tech/B.E.', 'MCA', 'M.Tech./M.E.', 'M.Sc. (Tech.)'],
#       dtype=object)

# %%
df.Degree.value_counts()
# Out:
# B.Tech/B.E.      3700
# MCA               243
# M.Tech./M.E.       53
# M.Sc. (Tech.)       2
# Name: Degree, dtype: int64

# %%
import seaborn as sns
sns.countplot(data=df,x=df.Degree)
# Out:
# <Axes: xlabel='Degree', ylabel='count'>

# %%
df.Designation.value_counts()
# Out:
# software engineer                    544
# software developer                   266
# system engineer                      205
# programmer analyst                   139
# systems engineer                     118
#                                     ...
# noc engineer                           1
# human resources associate              1
# human resources intern                 1
# senior quality assurance engineer      1
# jr. software developer                 1
# Name: Designation, Length: 384, dtype: int64

# %%
y=df.Designation.value_counts()[:10]
x=y.index
x,y
plt.bar(x,y)
plt.title("JOB CITY ")
plt.xlabel("CITY")
plt.ylabel("NO_OF_EMPLOYEES")
plt.xticks(rotation=90)
plt.show()

# %%
df.CollegeState.value_counts()
# Out:
# Uttar Pradesh        915
# Karnataka            370
# Tamil Nadu           367
# Telangana            319
# Maharashtra          262
# Andhra Pradesh       225
# West Bengal          196
# Punjab               193
# Madhya Pradesh       189
# Haryana              180
# Rajasthan            174
# Orissa               172
# Delhi                162
# Uttarakhand          113
# Kerala                33
# Jharkhand             28
# Chhattisgarh          27
# Gujarat               24
# Himachal Pradesh      16
# Bihar                 10
# Jammu and Kashmir      7
# Assam                  5
# Union Territory        5
# Sikkim                 3
# Meghalaya              2
# Goa                    1
# Name: CollegeState, dtype: int64

# %%
sns.countplot(data=df,x=df.CollegeState)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x=df.Specialization)
plt.xticks(rotation=90)
plt.show()

# %%
a
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience',
#        'Period', 'Age'],
#       dtype='object')

# %%
df.CollegeTier.value_counts()
# Out:
# 2    3701
# 1     297
# Name: CollegeTier, dtype: int64

# %%
sns.countplot(data=df,x=df.CollegeTier)
plt.xticks(rotation=90)
plt.show()

# %%
value_counts = df['GraduationYear'].value_counts(normalize=True)
# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Frequency of Values in Column')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ## UNIVARIATE ANALYSIS ON NUMERICAL CONTINUOUS COLUMNS

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience',
#        'Period', 'Age'],
#       dtype='object')

# %%
numerical_columns = ['English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
                     'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
                     'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
                     'agreeableness', 'extraversion', 'nueroticism',
                     'openess_to_experience','Salary','10percentage','12percentage','collegeGPA']

# %%
# Create subplots
import warnings
warnings.filterwarnings('ignore')
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(15, 20))
axes = axes.flatten()  # Flatten the 2D array of axes for easy indexing

# Loop through each numerical column and create KDE plot
for i, column in enumerate(numerical_columns):
    sns.kdeplot(df[column],color='blue', ax=axes[i])
    a=df[df[column]!=-1]
    sns.kdeplot(a[column],color='red', ax=axes[i])
    axes[i].set_title(f'KDE Plot for {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Density')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience',
#        'Period', 'Age'],
#       dtype='object')

# %%
sns.boxplot(data=df['Salary'])
# Out:
# <Axes: >

# %%
sns.histplot(df['English'],color='blue')
# Out:
# <Axes: xlabel='English', ylabel='Count'>

# %%
sns.boxplot(df['English'],color='red')
# Out:
# <Axes: >

# %%
numerical_column = ['English', 'Logical', 'Quant', 'ComputerProgramming',
                     'ElectronicsAndSemicon']
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 5))
axes = axes.flatten()  # Flatten the 2D array of axes for easy indexing

# Loop through each numerical column and create KDE plot
for i, column in enumerate(numerical_column):
    sns.boxplot(df[column],color='red', ax=axes[i])
    axes[i].set_title(f'BOX Plot for {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Density')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Create subplots
import warnings
warnings.filterwarnings('ignore')
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(15, 20))
axes = axes.flatten()  # Flatten the 2D array of axes for easy indexing

# Loop through each numerical column and create KDE plot
for i, column in enumerate(numerical_columns):
    sns.histplot(df[column],color='blue', ax=axes[i])
    a=df[df[column]!=-1]
    sns.histplot(a[column],color='red', ax=axes[i])
    axes[i].set_title(f'KDE Plot for {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Density')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
df['10board'].value_counts()
# Out:
# NOT MENTIONED      1684
# CBSE               1421
# ICSE                286
# UP BSE              166
# MP BSE               82
# MAHARASHTRA BSE      57
# Karnataka BSE        48
# Orissa BSE           45
# RJ BSE               43
# WB BSE               26
# Kerala BSE           24
# APBSE                21
# Jharkhand BSE        16
# Haryana BSE          14
# UK BSE               10
# Bihar BSE            10
# GJ BSE                9
# Punjab BSE            9
# HP BSE                9
# TN BSE                9
# AISSE                 5
# Assam BSE             2
# CG BSE                2
# Name: 10board, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x=df['10board'])
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience',
#        'Period', 'Age'],
#       dtype='object')

# %%
y
# Out:
# software engineer             544
# software developer            266
# system engineer               205
# programmer analyst            139
# systems engineer              118
# java software engineer        111
# software test engineer        102
# project engineer               77
# technical support engineer     76
# senior software engineer       72
# Name: Designation, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming y is your DataFrame column with top 10 values and their counts
y = df['12board'].value_counts()[:10]

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='12board', order=y.index)
plt.xticks(rotation=90)
plt.show()

# %%
df.Period.value_counts()
# Out:
# 1     1071
# 5      892
# 2      442
# 6      438
# 0      319
# 4      243
# 7      225
# 3      195
# 8      124
# 9       46
# 13       1
# 28       1
# 12       1
# Name: Period, dtype: int64

# %%
sns.countplot(data=df,x='Period')
# Out:
# <Axes: xlabel='Period', ylabel='count'>

# %%
import numpy as np
def outlier_treatment(datacolumn):
    sorted(datacolumn)
    Q1,Q3 = np.percentile(datacolumn , [25,70])
    IQR = Q3 - Q1
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
sns.boxplot(df['Period'],color='green')
# Out:
# <Axes: >

# %%
columns = ['Salary','10percentage','12percentage','English',
          'Logical','Quant','Domain', 'ComputerProgramming',
       'ElectronicsAndSemicon', 'ComputerScience', 'conscientiousness',
       'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience',
       'Age', 'Period']
df2 = df

# %%
for cols in columns:
    lowerbound, upperbound = outlier_treatment(df2[cols])

    df2 = df2.drop(df2[(df2[cols] < lowerbound) | (df2[cols] > upperbound)].index)

# %%
df
# Out:
#           ID     Salary        DOJ        DOL                  Designation  \
# 0     203097   420000.0 2012-06-01 2019-12-31      senior quality engineer
# 1     579905   500000.0 2013-09-01 2019-12-31            assistant manager
# 2     810601   325000.0 2014-06-01 2019-12-31             systems engineer
# 3     267447  1100000.0 2011-07-01 2019-12-31     senior software engineer
# 4     343523   200000.0 2014-03-01 2015-03-01                          get
# ...      ...        ...        ...        ...                          ...
# 3993   47916   280000.0 2011-10-01 2012-10-01            software engineer
# 3994  752781   100000.0 2013-07-01 2013-07-01             technical writer
# 3995  355888   320000.0 2013-07-01 2019-12-31  associate software engineer
# 3996  947111   200000.0 2014-07-01 2015-01-01           software developer
# 3997  324966   400000.0 2013-02-01 2019-12-31      senior systems engineer
#
# ...

# %%
df2
# Out:
#            ID    Salary        DOJ        DOL                  Designation  \
# 0      203097  420000.0 2012-06-01 2019-12-31      senior quality engineer
# 2      810601  325000.0 2014-06-01 2019-12-31             systems engineer
# 6      947847  300000.0 2014-08-01 2015-05-01       java software engineer
# 10      87291  600000.0 2011-04-01 2015-04-01         senior php developer
# 11     190393  450000.0 2011-08-01 2014-10-01      senior systems engineer
# ...       ...       ...        ...        ...                          ...
# 3988   466661  200000.0 2013-02-01 2013-07-01                 data analyst
# 3989  1204604  300000.0 2014-09-01 2019-12-31            software engineer
# 3995   355888  320000.0 2013-07-01 2019-12-31  associate software engineer
# 3996   947111  200000.0 2014-07-01 2015-01-01           software developer
# 3997   324966  400000.0 2013-02-01 2019-12-31      senior systems engineer
#
# ...

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %% [markdown]
# ## BIVARIATE ANALYSIS ON NUMERICAL VS CATEGORICAL COLUMN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   DOJ                    3998 non-null   datetime64[ns]
#  3   DOL                    3998 non-null   datetime64[ns]
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   datetime64[ns]
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
columns='Designation','GraduationYear','CollegeState','Degree','CollegeTier','Gender','JobCity','Period'

# %%
sns.boxplot(data=df,x='Gender',y='Salary')
sns.boxplot(data=df2,x='Gender',y='Salary')
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %%
sns.boxplot(data=df2,x='Gender',y='Salary')
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.boxplot(x='Gender', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('Gender values')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.boxplot(x='Gender', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('Gender values')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.boxplot(x='GraduationYear', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('GraduationYear')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.boxplot(x='GraduationYear', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('GraduationYear')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
df.GraduationYear.value_counts()
# Out:
# 2013    1181
# 2014    1037
# 2012     847
# 2011     507
# 2010     292
# 2015      94
# 2009      24
# 2017       8
# 2016       7
# 2007       1
# Name: GraduationYear, dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.boxplot(x='Degree', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('Degree')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.boxplot(x='Degree', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('Degree')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 5), sharey=True)

# Box plot with outliers
sns.boxplot(x='Period', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('Experiance')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.boxplot(x='Period', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('Experiance')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.boxplot(x='CollegeTier', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('College Tier')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.boxplot(x='CollegeTier', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('College Tier')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## BIVARIATE ANALYSIS ON NUMEREICAL VS NUMERICAL COLUMNS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   DOJ                    3998 non-null   datetime64[ns]
#  3   DOL                    3998 non-null   datetime64[ns]
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   datetime64[ns]
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
df
# Out:
#           ID     Salary        DOJ        DOL                  Designation  \
# 0     203097   420000.0 2012-06-01 2019-12-31      senior quality engineer
# 1     579905   500000.0 2013-09-01 2019-12-31            assistant manager
# 2     810601   325000.0 2014-06-01 2019-12-31             systems engineer
# 3     267447  1100000.0 2011-07-01 2019-12-31     senior software engineer
# 4     343523   200000.0 2014-03-01 2015-03-01                          get
# ...      ...        ...        ...        ...                          ...
# 3993   47916   280000.0 2011-10-01 2012-10-01            software engineer
# 3994  752781   100000.0 2013-07-01 2013-07-01             technical writer
# 3995  355888   320000.0 2013-07-01 2019-12-31  associate software engineer
# 3996  947111   200000.0 2014-07-01 2015-01-01           software developer
# 3997  324966   400000.0 2013-02-01 2019-12-31      senior systems engineer
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   DOJ                    3998 non-null   datetime64[ns]
#  3   DOL                    3998 non-null   datetime64[ns]
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   datetime64[ns]
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
a=df.select_dtypes(include=['float64','int64'])

# %%
a.columns
# Out:
# Index(['ID', 'Salary', '10percentage', '12graduation', '12percentage',
#        'CollegeID', 'CollegeTier', 'collegeGPA', 'CollegeCityID',
#        'CollegeCityTier', 'GraduationYear', 'English', 'Logical', 'Quant',
#        'Domain', 'ComputerProgramming', 'ElectronicsAndSemicon',
#        'ComputerScience', 'MechanicalEngg', 'ElectricalEngg', 'TelecomEngg',
#        'CivilEngg', 'conscientiousness', 'agreeableness', 'extraversion',
#        'nueroticism', 'openess_to_experience', 'Period', 'Age'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.scatterplot(x='Period', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('Period')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.scatterplot(x='Period', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('Period')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.scatterplot(x='collegeGPA', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('Colloege CGPA')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.scatterplot(x='collegeGPA', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('College CGPA')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.scatterplot(x='ComputerProgramming', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('ComputerProgramming')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.scatterplot(x='ComputerProgramming', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('ComputerProgramming')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.scatterplot(x='10percentage', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('10percentage')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.scatterplot(x='10percentage', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('10percentage')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.scatterplot(x='12percentage', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('12percentage')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.scatterplot(x='12percentage', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('12percentage')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.scatterplot(x='English', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('English')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.scatterplot(x='English', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('English')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.scatterplot(x='openess_to_experience', y='Salary', data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('openess_to_experience')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.scatterplot(x='openess_to_experience', y='Salary', data=df2, color='pink', ax=ax[1])
ax[1].set_xlabel('openess_to_experience')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
# Group by 'Gender' and 'Salary' column and then apply cumulative sum
grouped_df = df.groupby('Gender')['Salary'].sum().groupby(level=0).cumsum()

# Plot the line graph
grouped_df.plot(kind='line', marker='o', figsize=(10, 6))

# Add labels and title
plt.title('Line Graph of Cumulative Salary by Gender')
plt.xlabel('Index')
plt.ylabel('Cumulative Salary')
plt.xticks(rotation=0)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2]),
#  [Text(-0.2, 0, ''),
#   Text(0.0, 0, 'f'),
#   Text(0.2, 0, ''),
#   Text(0.4000000000000001, 0, ''),
#   Text(0.6000000000000001, 0, ''),
#   Text(0.8, 0, ''),
#   Text(1.0000000000000002, 0, ''),
#   Text(1.2000000000000002, 0, '')])

# %%
a=df.select_dtypes(include='object')
a.columns
# Out:
# Index(['Designation', 'JobCity', 'Gender', '10board', '12board', 'Degree',
#        'Specialization', 'CollegeState'],
#       dtype='object')

# %% [markdown]
# ## BIVARIATE ANALYSIS ON CATEGORICAL COLUMNS

# %%
a=pd.crosstab(df['Degree'], df['Gender'])
a
# Out:
# Gender           f     m
# Degree
# B.Tech/B.E.    889  2811
# M.Sc. (Tech.)    1     1
# M.Tech./M.E.     9    44
# MCA             58   185

# %%
a.plot(kind='bar', stacked=False, figsize=(10, 6))

# Add labels and title
plt.title('Stacked Bar Graph of Degrees by Gender')
plt.xlabel('Degree')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
a=pd.crosstab(df['Degree'], df.CollegeTier)
a.plot(kind='bar', stacked=False, figsize=(10, 6))

# Add labels and title
plt.title('Stacked Bar Graph of Degrees by college tier')
plt.xlabel('Degree')
plt.ylabel('Count')
a
# Out:
# CollegeTier      1     2
# Degree
# B.Tech/B.E.    269  3431
# M.Sc. (Tech.)    1     1
# M.Tech./M.E.    15    38
# MCA             12   231

# %%
a=pd.crosstab(df.CollegeState, df.Degree)
a.plot(kind='bar', stacked=False, figsize=(10, 6))

# Add labels and title
plt.title('Stacked Bar Graph of Degrees by Degree')
plt.xlabel('Degree')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.scatterplot(data=df, x="English", y="Quant")
plt.show()

# %% [markdown]
# ## MultiVAriate Analysis

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.boxplot(x='Degree', y='Salary', hue='Gender',data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('Degree')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.boxplot(x='Degree', y='Salary', hue='Gender',data=df2, color='green', ax=ax[1])
ax[1].set_xlabel('Degree')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Box plot with outliers
sns.boxplot(x='CollegeTier', y='Salary', hue='Gender',data=df, color='orange', ax=ax[0])
ax[0].set_ylabel('Salary')
ax[0].set_xlabel('College Tier')
ax[0].set_title('With Outliers')

# Box plot without outliers
sns.boxplot(x='CollegeTier', y='Salary', hue='Gender',data=df2, color='green', ax=ax[1])
ax[1].set_xlabel('College Tier')
ax[1].set_title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 10))
a=df.corr()
sns.heatmap(a,cmap='coolwarm',fmt=".1f")

# Add labels and title
plt.title('Heatmap of Salary Statistics')
plt.xlabel('Statistic')
plt.ylabel('Gender')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Research Questions
#     Times of India article dated Jan 18, 2019 states that “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.” Test this claim with the data given to you.
#     Is there a relationship between gender and specialization? (i.e. Does the preference of Specialisation depend on the Gender?)

# %% [markdown]
# ## Visualization Analysis

# %%
df
# Out:
#           ID     Salary        DOJ        DOL                  Designation  \
# 0     203097   420000.0 2012-06-01 2019-12-31      senior quality engineer
# 1     579905   500000.0 2013-09-01 2019-12-31            assistant manager
# 2     810601   325000.0 2014-06-01 2019-12-31             systems engineer
# 3     267447  1100000.0 2011-07-01 2019-12-31     senior software engineer
# 4     343523   200000.0 2014-03-01 2015-03-01                          get
# ...      ...        ...        ...        ...                          ...
# 3993   47916   280000.0 2011-10-01 2012-10-01            software engineer
# 3994  752781   100000.0 2013-07-01 2013-07-01             technical writer
# 3995  355888   320000.0 2013-07-01 2019-12-31  associate software engineer
# 3996  947111   200000.0 2014-07-01 2015-01-01           software developer
# 3997  324966   400000.0 2013-02-01 2019-12-31      senior systems engineer
#
# ...

# %%
a=df.Designation.unique()
pd.set_option('display.max_rows', None)
a.sort()

# %%
a
# Out:
# array(['.net developer', 'account executive', 'account manager',
#        'admin assistant', 'administrative coordinator',
#        'administrative support', 'aircraft technician',
#        'android developer', 'application developer',
#        'application engineer', 'application support engineer',
#        'apprentice', 'asp.net developer', 'assistant administrator',
#        'assistant electrical engineer', 'assistant engineer',
#        'assistant manager', 'assistant professor', 'assistant programmer',
#        'assistant software engineer', 'assistant store manager',
#        'assistant system engineer', 'assistant system engineer trainee',
#        'associate developer', 'associate engineer', 'associate manager',
#        'associate qa', 'associate software developer',
#        'associate software engineer', 'associate system engineer',
#        'associate technical operations', 'associate test engineer',
#        'asst. manager', 'automation engineer', 'branch manager',
# ...

# %%
df['Designation'] = df['Designation'].replace([
    'programmer analyst trainee', 'programmer analyst','program analyst trainee'
], 'programmer analyst'
)

df['Designation'] = df['Designation'].replace([
    'software eng', 'software engg', 'software engineer', 'software engineere', 'software enginner','software engineer analyst','software engineer associate'
    ,'software engineer trainee','software engineering associate'
], 'software engineer'
)

# %%
df.Designation.value_counts().sort_index()
# Out:
# .net developer                                      39
# account executive                                    4
# account manager                                      1
# admin assistant                                      2
# administrative coordinator                           1
# administrative support                               1
# aircraft technician                                  1
# android developer                                   46
# application developer                               52
# application engineer                                22
# application support engineer                         3
# apprentice                                           3
# asp.net developer                                   26
# assistant administrator                              1
# assistant electrical engineer                        2
# assistant engineer                                   4
# assistant manager                                   52
# ...

# %%
df.Specialization.value_counts().sort_index()
# Out:
# aeronautical engineering                         3
# applied electronics and instrumentation          9
# automobile/automotive engineering                5
# biomedical engineering                           2
# biotechnology                                   15
# ceramic engineering                              1
# chemical engineering                             9
# civil engineering                               29
# computer and communication engineering           1
# computer application                           244
# computer engineering                           600
# computer networking                              1
# computer science and engineering               752
# control and instrumentation engineering          1
# electrical and power engineering                 2
# electrical engineering                          82
# electronics                                      1
# electronics & telecommunications               121
# ...

# %%
df3=df[df["Specialization"].isin(["computer science & engineering", "computer engineering"])]

# %%
df3.Designation.value_counts()
# Out:
# software engineer                        110
# software developer                        49
# system engineer                           41
# programmer analyst                        26
# senior software engineer                  24
# software test engineer                    20
# systems engineer                          20
# java software engineer                    17
# application developer                     14
# project engineer                          13
# programmer                                11
# technical support engineer                10
# senior systems engineer                    9
# associate software engineer                9
# java developer                             9
# network engineer                           9
# test engineer                              8
# quality analyst                            8
# senior software developer                  8
# php developer                              8
# web developer                              7
# ...

# %%
df3 = df3[df3["Designation"].isin(["programmer analyst", "software engineer", "hardware engineer", "associate engineer"])]

# %%
df3
# Out:
#            ID     Salary        DOJ        DOL         Designation  \
# 19     466888   325000.0 2014-09-01 2019-12-31   software engineer
# 20     140069   320000.0 2010-11-01 2012-09-01   software engineer
# 36     602377   270000.0 2013-03-01 2019-12-31   software engineer
# 44     247617   380000.0 2012-05-01 2015-04-01  programmer analyst
# 59     536053   120000.0 2009-09-01 2013-04-01   software engineer
# 76     361583   800000.0 2012-06-01 2019-12-31   software engineer
# 120    483864   500000.0 2012-10-01 2019-12-31   software engineer
# 170    467560   235000.0 2012-10-01 2015-04-01   software engineer
# 175    509882   450000.0 2013-02-01 2019-12-31   software engineer
# 187    336792   410000.0 2013-02-01 2019-12-31  programmer analyst
# 200    283267   440000.0 2013-10-01 2015-04-01   software engineer
# 227    190981   550000.0 2011-07-01 2013-07-01   software engineer
# 243    329402   265000.0 2012-07-01 2014-07-01   software engineer
# ...

# %%
df3.Designation.value_counts()
# Out:
# software engineer     110
# programmer analyst     26
# associate engineer      1
# Name: Designation, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.boxplot(x='Designation', y='Salary', data=df3,ax=ax)

plt.yscale('symlog')  # Set logarithmic scale for y-axis
plt.title('Box Plot of Salary Across Specializations (Logarithmic Scale)')
plt.xlabel('Specialization')
plt.ylabel('Salary')
ax.axhline(df3['Salary'].mean(), color='k',
           linestyle=':')
plt.show()

# %%
a=df3.Salary.mean()
a
# Out:
# 383649.63503649633

# %% [markdown]
# ## STATISTICAL ANALYSIS ON SALARY RANGE 2.5L to 3.0L

# %%
from scipy.stats import ttest_1samp

prog_analyst_salaries = df3.loc[df3['Designation'] == 'programmer analyst', 'Salary'].values
software_eng_salaries = df3.loc[df3['Designation'] == 'software engineer', 'Salary'].values
hardware_eng_salaries = df3.loc[df3['Designation'] == 'hardware engineer', 'Salary'].values
assoc_eng_salaries = df3.loc[df3['Designation'] == 'associate engineer', 'Salary'].values

expected_range = (250000, 300000)

for job, salaries in [("programmer analyst", prog_analyst_salaries),
                      ("software engineer", software_eng_salaries),
                      ("hardware engineer", hardware_eng_salaries),
                      ("associate engineer", assoc_eng_salaries)]:

    t_stat, p_val = ttest_1samp(salaries, expected_range[0], alternative='greater')

    print(f"One-sample t-test for {job}:")
    print(f"  t_critical: {t_stat:.2f}")
    print(f"  p_value: {p_val:.5e}")

    if p_val < 0.05:
        print("  Result: There is sufficent evidence to reject the Null Hypothesis\n")
    else:
        print("  Result: There is not enough evidence to reject the Null Hypothesis\n")
# Out:
# One-sample t-test for programmer analyst:
#   t_critical: 9.75
#   p_value: 2.65118e-10
#   Result: There is sufficent evidence to reject the Null Hypothesis
#
# One-sample t-test for software engineer:
#   t_critical: 7.58
#   p_value: 6.09466e-12
#   Result: There is sufficent evidence to reject the Null Hypothesis
#
# One-sample t-test for hardware engineer:
#   t_critical: nan
#   p_value: nan
#   Result: There is not enough evidence to reject the Null Hypothesis
#
# One-sample t-test for associate engineer:
#   t_critical: nan
#   p_value: nan
#   Result: There is not enough evidence to reject the Null Hypothesis

# %%
from scipy.stats import chi2
from scipy.stats import chi2_contingency
observed = pd.crosstab(df3.Specialization, df3.Gender)
print(observed)
chi2_contingency(observed)
chi2_test_stat = chi2_contingency(observed)[0]
pval = chi2_contingency(observed)[1]
ddof = chi2_contingency(observed)[2]
confidence_level = 0.90

alpha = 1 - confidence_level

chi2_critical = chi2.ppf(1 - alpha, ddof)

print('critical: ',chi2_critical)

# Setting Chi2 Critical value 
chi2_critical_right = chi2_critical

if(chi2_test_stat > chi2_critical):
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Gender                 f   m
# Specialization
# computer engineering  44  93
# critical:  nan
# Fail to Reject Null Hypothesis
